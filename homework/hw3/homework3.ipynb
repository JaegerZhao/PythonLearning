# %%
'''
使用numpy与matplotlib在jupyter中绘制正弦与余弦曲线，并显示图例。
'''
# 导入模块
import numpy as np
import matplotlib.pyplot as plt
fig = plt.figure('Sine Wave', (6,3))
#创建axisartist对象
ax = axisartist.Subplot(fig, 1,1,1)
#增加坐标系
fig.add_axes(ax)
#坐标设置不显示
ax.axis[:].set_visible(False)
#指定坐标系位置
ax.axis["x"] = ax.new_floating_axis(0, 0)
ax.axis["y"] = ax.new_floating_axis(1, 0)
ax.axis["x"].set_axis_direction('top')
ax.axis["y"].set_axis_direction('left')
#设置坐标轴格式
ax.axis["x"].set_axisline_style("->", size = 1.0)
ax.axis["y"].set_axisline_style("->", size = 1.0)
# 创建数据
x = np.linspace(0, 2 * np.pi, 100) # 从0到2π平均取100个点
y_sin = np.sin(x) # 计算正弦值
y_cos = np.cos(x) # 计算余弦值

# 绘制图形
ax.plot(x, y_sin, color="red", linestyle="-", label="正弦") # 绘制红色实线，标签为正弦
ax.plot(x, y_cos, color="blue", linestyle="--", label="余弦") # 绘制蓝色虚线，标签为余弦
plt.title("正弦与余弦曲线") # 设置标题
plt.legend(loc="best") # 显示图例，并自动选择最佳位置

#设置x轴刻度
ax.set_xticks(np.linspace(0,2,5)*np.pi)
ax.set_xticklabels(['','$\\frac{\pi}{2}$', '$\pi$', '$\\frac{3\pi}{2}$', '$2\pi$'])
ax.set_yticks([0, 1])

# 显示图形
plt.show()
